# %% [markdown]
# <a href="https://colab.research.google.com/github/Sevenc1over/AI-class/blob/main/10%EC%A3%BC%EC%B0%A8/%ED%85%90%EC%84%9C%ED%94%8C%EB%A1%9C%EC%9A%B0_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns

def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)

    loaded = np.dstack(loaded)
    return loaded

def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y

def load_dataset(prefix=''):
    # load all train
    trainX, trainy = load_dataset_group('train', prefix + '/content/drive/MyDrive/UCI HAR Dataset/')
    # load all test
    testX, testy = load_dataset_group('test', prefix + '/content/drive/MyDrive/UCI HAR Dataset/')

    #zero-offset class values
    trainy = trainy - 1
    testy = testy - 1
    #one hot encode y
    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)
    print(trainX.shape, trainy.shape, trainy_one_hot.shape, testX.shape, testy.shape, testy_one_hot.shape)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()

#스케일링
from sklearn.preprocessing import StandardScaler

# 원래 shape 저장
n_samples, n_timesteps, n_features = trainX.shape

# (7352*128, 9) 형태로 변환 — 모든 시점의 feature를 하나로 봄
scaler = StandardScaler()
trainX = scaler.fit_transform(trainX.reshape(-1, n_features)).reshape(n_samples, n_timesteps, n_features)
testX = scaler.transform(testX.reshape(-1, n_features)).reshape(testX.shape)

from sklearn.model_selection import train_test_split

X_train,X_val,y_train_one_hot,y_val_one_hot,y_train,y_val=train_test_split(trainX, trainy_one_hot, trainy,test_size=0.2,random_state=100)

X_train.shape,X_val.shape,y_train_one_hot.shape,y_val_one_hot.shape,y_train.shape,y_val.shape
# Out:
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-3958942637.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# (7352, 128, 9) (7352, 1) (7352, 6) (2947, 128, 9) (2947, 1) (2947, 6)
# ((5881, 128, 9), (1471, 128, 9), (5881, 6), (1471, 6), (5881, 1), (1471, 1))

# %%
import tensorflow as tf

model_LSTM = tf.keras.Sequential([
    tf.keras.Input(shape=(X_train.shape[1], X_train.shape[2])),
    tf.keras.layers.LSTM(units=64),
    tf.keras.layers.Dense(units=y_train_one_hot.shape[1], activation='softmax') # Changed units and added softmax for classification
])

# %%
model_LSTM.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history_lstm = model_LSTM.fit(X_train, y_train_one_hot, epochs=50, batch_size=8, verbose=1, validation_data=(X_val, y_val_one_hot))
# Out:
# Epoch 1/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.6598 - loss: 0.8783 - val_accuracy: 0.9035 - val_loss: 0.2876
# Epoch 2/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9021 - loss: 0.2668 - val_accuracy: 0.8674 - val_loss: 0.3143
# Epoch 3/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9225 - loss: 0.2255 - val_accuracy: 0.9443 - val_loss: 0.1494
# Epoch 4/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9394 - loss: 0.1538 - val_accuracy: 0.9409 - val_loss: 0.1434
# Epoch 5/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9426 - loss: 0.1670 - val_accuracy: 0.9211 - val_loss: 0.1654
# Epoch 6/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9549 - loss: 0.1148 - val_accuracy: 0.9443 - val_loss: 0.1287
# Epoch 7/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9557 - loss: 0.1153 - val_accuracy: 0.9524 - val_loss: 0.1216
# Epoch 8/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9525 - loss: 0.1134 - val_accuracy: 0.9211 - val_loss: 0.1835
# Epoch 9/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9356 - loss: 0.1656 - val_accuracy: 0.9511 - val_loss: 0.1161
# Epoch 10/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9590 - loss: 0.1064 - val_accuracy: 0.9517 - val_loss: 0.1163
# Epoch 11/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9534 - loss: 0.1118 - val_accuracy: 0.9409 - val_loss: 0.1292
# Epoch 12/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9535 - loss: 0.1162 - val_accuracy: 0.9409 - val_loss: 0.1273
# Epoch 13/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9468 - loss: 0.1289 - val_accuracy: 0.9415 - val_loss: 0.1339
# Epoch 14/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9443 - loss: 0.1468 - val_accuracy: 0.9279 - val_loss: 0.1531
# Epoch 15/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9429 - loss: 0.1331 - val_accuracy: 0.9320 - val_loss: 0.1266
# Epoch 16/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9505 - loss: 0.1211 - val_accuracy: 0.9436 - val_loss: 0.1292
# Epoch 17/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9453 - loss: 0.1193 - val_accuracy: 0.9477 - val_loss: 0.1398
# Epoch 18/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9557 - loss: 0.1074 - val_accuracy: 0.9395 - val_loss: 0.1262
# Epoch 19/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9584 - loss: 0.1027 - val_accuracy: 0.9477 - val_loss: 0.1113
# Epoch 20/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9592 - loss: 0.1080 - val_accuracy: 0.9463 - val_loss: 0.1251
# Epoch 21/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9482 - loss: 0.1260 - val_accuracy: 0.9497 - val_loss: 0.1203
# Epoch 22/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9550 - loss: 0.1089 - val_accuracy: 0.9477 - val_loss: 0.1266
# Epoch 23/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9572 - loss: 0.1066 - val_accuracy: 0.9531 - val_loss: 0.1118
# Epoch 24/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9568 - loss: 0.1041 - val_accuracy: 0.9477 - val_loss: 0.1111
# Epoch 25/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9565 - loss: 0.0924 - val_accuracy: 0.9531 - val_loss: 0.1095
# Epoch 26/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9595 - loss: 0.0958 - val_accuracy: 0.9504 - val_loss: 0.1159
# Epoch 27/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9553 - loss: 0.1066 - val_accuracy: 0.9511 - val_loss: 0.1136
# Epoch 28/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9671 - loss: 0.0904 - val_accuracy: 0.9463 - val_loss: 0.1123
# Epoch 29/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9598 - loss: 0.1019 - val_accuracy: 0.9409 - val_loss: 0.1293
# Epoch 30/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9518 - loss: 0.1169 - val_accuracy: 0.9538 - val_loss: 0.1124
# Epoch 31/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9589 - loss: 0.0965 - val_accuracy: 0.9504 - val_loss: 0.1277
# Epoch 32/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9583 - loss: 0.1036 - val_accuracy: 0.9490 - val_loss: 0.1157
# Epoch 33/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9587 - loss: 0.0967 - val_accuracy: 0.9558 - val_loss: 0.1089
# Epoch 34/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.9606 - loss: 0.0992 - val_accuracy: 0.9558 - val_loss: 0.1036
# Epoch 35/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9614 - loss: 0.0871 - val_accuracy: 0.9497 - val_loss: 0.1418
# Epoch 36/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9486 - loss: 0.1291 - val_accuracy: 0.9497 - val_loss: 0.1172
# Epoch 37/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9601 - loss: 0.1018 - val_accuracy: 0.9531 - val_loss: 0.1134
# Epoch 38/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9603 - loss: 0.0987 - val_accuracy: 0.9436 - val_loss: 0.1144
# Epoch 39/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9562 - loss: 0.0995 - val_accuracy: 0.9490 - val_loss: 0.1243
# Epoch 40/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9640 - loss: 0.0954 - val_accuracy: 0.8878 - val_loss: 0.4959
# Epoch 41/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9421 - loss: 0.1386 - val_accuracy: 0.9436 - val_loss: 0.1319
# Epoch 42/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9591 - loss: 0.1039 - val_accuracy: 0.9504 - val_loss: 0.1101
# Epoch 43/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9599 - loss: 0.0936 - val_accuracy: 0.9531 - val_loss: 0.1039
# Epoch 44/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9635 - loss: 0.0880 - val_accuracy: 0.9504 - val_loss: 0.1069
# Epoch 45/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9630 - loss: 0.0914 - val_accuracy: 0.9504 - val_loss: 0.0974
# Epoch 46/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9502 - loss: 0.0985 - val_accuracy: 0.9585 - val_loss: 0.0898
# Epoch 47/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9591 - loss: 0.0857 - val_accuracy: 0.9551 - val_loss: 0.0918
# Epoch 48/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9641 - loss: 0.0819 - val_accuracy: 0.9579 - val_loss: 0.0814
# Epoch 49/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9658 - loss: 0.0789 - val_accuracy: 0.9517 - val_loss: 0.0992
# Epoch 50/50
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9590 - loss: 0.0834 - val_accuracy: 0.9572 - val_loss: 0.0882

# %%
# loss 체크
import matplotlib.pyplot as plt

N_EPOCHS = 50 # 에포크 수 정의
history = history_lstm # 학습 히스토리 변수 사용

plt.figure(figsize=(10,7))
plt.plot(range(N_EPOCHS), history.history['accuracy'], label='train accuracy')
plt.plot(range(N_EPOCHS), history.history['val_accuracy'], label='validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# loss 체크
import matplotlib.pyplot as plt

N_EPOCHS = 50 # 에포크 수 정의
history = history_lstm # 학습 히스토리 변수 사용

plt.figure(figsize=(10,7))
plt.plot(range(N_EPOCHS), history.history['loss'], label='train loss')
plt.plot(range(N_EPOCHS), history.history['val_loss'], label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
test_loss, test_acc = model_LSTM.evaluate(testX, testy_one_hot)
print(f"Test accuracy: {test_acc:.2%}")
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8576 - loss: 0.4323
# Test accuracy: 90.70%
